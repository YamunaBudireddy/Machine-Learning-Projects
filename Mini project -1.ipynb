# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\YAMUNA\OneDrive\Documents\TEMP.csv")
df
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df.isnull()
# Out:
#    Temperature  Humidity   city
# 0        False     False  False
# 1        False     False  False
# 2        False     False  False
# 3        False     False  False
# 4        False     False  False
# 5        False     False  False
# 6        False     False  False

# %% [markdown]
# # exploring data

# %%
df.head()
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad

# %%
df.tail()
# Out:
#    Temperature  Humidity       city
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df['Temperature']=df['Temperature'].fillna(df['Temperature'].mean())
df
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df['Humidity']=df['Humidity'].fillna(df['Humidity'].sum())
df
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df.shape
# Out:
# (7, 3)

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'city'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.dtypes
# Out:
# Temperature     int64
# Humidity        int64
# city           object
# dtype: object

# %%
df.city
# Out:
# 0    Hyderabad
# 1    Hyderabad
# 2    Hyderabad
# 3    Hyderabad
# 4    Hyderabad
# 5      Chennai
# 6      Chennai
# Name: city, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai>

# %%
df[2:6]
# Out:
#    Temperature  Humidity       city
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai

# %% [markdown]
# # creating database

# %%
data=({
    "Name":["Niha","Kavs","Vinay","Sri","Sai","Sagarika","Raju"],
    "Age": [12,23,45,67,23,23,12]
})
df
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df.tail()
# Out:
#    Temperature  Humidity       city
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai

# %%
df.head()
# Out:
#    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad

# %%
df.shape
# Out:
# (7, 3)

# %%
df.dtypes
# Out:
# Temperature     int64
# Humidity        int64
# city           object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.isnull()
# Out:
#    Temperature  Humidity   city
# 0        False     False  False
# 1        False     False  False
# 2        False     False  False
# 3        False     False  False
# 4        False     False  False
# 5        False     False  False
# 6        False     False  False

# %%
df.info
# Out:
# <bound method DataFrame.info of    Temperature  Humidity       city
# 0           34        50  Hyderabad
# 1           24        45  Hyderabad
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai
# 6           89        78    Chennai>

# %%
df[2:6]
# Out:
#    Temperature  Humidity       city
# 2           34        36  Hyderabad
# 3           12        56  Hyderabad
# 4           67        78  Hyderabad
# 5           78        89    Chennai

# %%
df['Temperature']=df['Temperature'].fillna(df['Temperature'].mean())
